# %%
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# 1360, 800

# %%
def replace_0(class_):
    if class_ == 0:
        return 43
    else:
        return class_

# %%
df = pd.read_csv('gt.txt', sep=';', names=['filename', 'xmin', 'ymin', 'xmax', 'ymax', 'class'])

# %%
df['width'] = 1360
df['height'] = 800

# %%
df[['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']]
# Out:
#        filename  width  height  class  xmin  ymin  xmax  ymax
# 0     00000.ppm   1360     800     11   774   411   815   446
# 1     00001.ppm   1360     800     40   983   388  1024   432
# 2     00001.ppm   1360     800     38   386   494   442   552
# 3     00001.ppm   1360     800     13   973   335  1031   390
# 4     00002.ppm   1360     800     39   892   476  1006   592
# ...         ...    ...     ...    ...   ...   ...   ...   ...
# 1208  00896.ppm   1360     800     15   808   412   846   450
# 1209  00897.ppm   1360     800     42   804   526   828   550
# 1210  00898.ppm   1360     800      4   323   504   355   536
# 1211  00898.ppm   1360     800      4   817   510   849   542
# 1212  00899.ppm   1360     800     24   864   484   921   534
#
# [1213 rows x 8 columns]

# %%
df['class'] = df['class'].map(replace_0)

# %%
def replace_ppm(name):
    name = name.split('.')
    return name[0] + '.jpeg'

# %%
df['filename'] = df['filename'].map(replace_ppm)

# %%
df = df[['filename', 'width', 'height', 'xmin', 'ymin', 'xmax', 'ymax', 'class']]

# %%
df.to_csv('labels_data.csv', index=False)

# %%
df.head()
# Out:
#      filename  width  height  xmin  ymin  xmax  ymax  class
# 0  00000.jpeg   1360     800   774   411   815   446     11
# 1  00001.jpeg   1360     800   983   388  1024   432     40
# 2  00001.jpeg   1360     800   386   494   442   552     38
# 3  00001.jpeg   1360     800   973   335  1031   390     13
# 4  00002.jpeg   1360     800   892   476  1006   592     39

# %%
img = cv2.imread('00001.jpeg')
plt.imshow(img)
